# %%
import pandas as pd
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
from time import sleep

# %%
df_action = pd.read_csv("FASE_API_1/Action.csv")

idOwner = []

for i in df_action["idOwner"]:
    idOwner.append(i)
    

print(idOwner)

print(len(idOwner))
# Out:
# ['tt0077634', 'tt0076709', 'tt0078428', 'tt0077645', 'tt0079106', 'tt0078941', 'tt0078726', 'tt0078918', 'tt0079712', 'tt0079896', 'tt0079888', 'tt0080501', 'tt0080441', 'tt0080514', 'tt0080481', 'tt0079899', 'tt0080872', 'tt0082133', 'tt0082338', 'tt0082673', 'tt0082250', 'tt0082532', 'tt0078393', 'tt0082566', 'tt0083062', 'tt0084256', 'tt0084297', 'tt0084540', 'tt0084836', 'tt0083061', 'tt0083541', 'tt0085289', 'tt0085454', 'tt0085312', 'tt0084279', 'tt0085460', 'tt0085540', 'tt0084738', 'tt0083509', 'tt0086566', 'tt0088137', 'tt0087130', 'tt0066151', 'tt0081236', 'tt0084668', 'tt0086930', 'tt0089861', 'tt0087368', 'tt0089930', 'tt0090170', 'tt0088962', 'tt0090302', 'tt0089563', 'tt0091012', 'tt0090847', 'tt0090956', 'tt0090902', 'tt0090587', 'tt0092841', 'tt0092787', 'tt0093171', 'tt0091285', 'tt0093983', 'tt0092582', 'tt0093663', 'tt0090334', 'tt0094386', 'tt0094384', 'tt0094607', 'tt0092531', 'tt0094620', 'tt0090869', 'tt0092926', 'tt0094376', 'tt0094004', 'tt0093989', 'tt0095095', 'tt0095290', 'tt0096469', 'tt0094926', 'tt0097318', 'tt0097864', 'tt0095335', 'tt0097064', 'tt0099814', 'tt0099793', 'tt0100195', 'tt0101828', 'tt0101288', 'tt0102073', 'tt0096090', 'tt0101928', 'tt0105881', 'tt0109178', 'tt0109033', 'tt0109536']
# 96

# %%
nota = []
nombre = []

driver = webdriver.Chrome()

notas_imdb =[]

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()


for i in idOwner [:10]:
    driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
    nota.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text)
    nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)

print(nota)
# Out:
# ['4,7', '5,1', '6,3', '5,2', '5,8', '5,9', '5,4', '5,3', '7,4', '6,3']

# %%
# EXTRACCION DATOS IMDB Y LO GUARDAMOS EN LISTAS

driver = webdriver.Chrome()

notas_imdb =[]

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()

nota = []
director = []
guionista = []
argumento = []
duracion = []
nombre = []

for i in idOwner:
    driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
    sleep(5)
    nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
    try:
        nota.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text)
    except:
        nota.append(None)
    try:        
        director.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a').text)                                                                                   
        guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div').text)
        
                                                                   
    except:
         
        director.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a').text)                                                  
        guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a').text)                                                   
    
    try:
        duracion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > ul > li:nth-child(3)').text)  
    except:
        try:
            duracion.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/ul/li[2]').text)

        except:
            duracion.append(None)
     
    try:
        argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr').text)
    except:
        argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-2.PeLXr').text)
                                                                      

driver.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      22 for i in idOwner:
#      23     driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
# ---> 24     sleep(5)
#      25     nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
#      26     try:
#
# KeyboardInterrupt:

# %%
print(tuple(zip(nombre,nota,director,guionista,duracion,argumento)))
# Out:
# (('El gran desafío en helicóptero', '4,7', 'Lawrence David Foldes', 'Lawrence David FoldesHenry EdwardsTony Crechales', '1h 36min', 'Cuando se descubre petróleo en un pequeño pueblo, unos codiciosos buscadores contratan salvajes moteros para ahuyentar a los habitantes. Sin embargo, cuando un grupo de jóvenes pilotos se topa con la trama, planean una represalia.'), ('El último combate', '5,1', 'See-Yuen Ng', 'Tin-Shing Ho', '1h 36min', 'Mientras investigaba la muerte de su amigo Chin Ku, Billy Lo es muerto. Su hermano menor, Bobby Lo, investiga ambas muertes'), ('Shao Lin yu Wu Dang', '6,3', 'Cheh Chang', 'Cheh ChangKuang Ni', '1h 41min', 'The Wu Tang chief sends out his men, each of whom is given a symbol so they can recognize each other. The largest is given to Lee, whom the others are to obey.'), ('Duelo del Dragón y el Tigre', '5,2', 'Bruce Le', 'Bruce LeFan Pan', '1h 28min', 'Dos agentes de la CIA, un maestro de kung fu y un mujeriego elegante, siguen la pista de la fórmula robada de una droga superesterilizante desde España hasta Hong Kong, luchando contra terroristas neonazis.'), ("L'empreinte des géants", '5,8', 'Robert Enrico', 'François ChevallierHortense DufourRobert Enrico', '2h 21min', 'The life of workers and their families in a construction site of a highway in 1965.'), ('Carlos el terrorista', '5,9', 'René Cardona', 'René Cardona Jr.', '1h 37min', "After killing his underworld boss, a man turns to the CIA for help, but finds the opposite extreme of terrorism, as he must answer to the CIA's double cross demands for the return of his kidnapped family."), ('Ba jue', '5,4', 'Hsueh-Li Pao', 'Shu-Mei ChinYu ChuKuang Ni', '1h 38min', 'A new bandit with superb kung fu causes panic and fear among the merchants of Wuiyang County. The merchants hire Wu Chin Ping to escort boxes of beautiful and previous stones to Wuiyang County. Wu gathers a group of experienced and courageous martial artists to protect the treasure and kill the masked bandit.'), ('La espada del samurái', '5,3', 'Tsugunobu Kotani', 'William Overgard', '1h 44min', 'Una espada samurái de acero que iba a ser entregada al embajador americano por el emperador de Japón es robada. Marineros estadounidenses y samuráis japoneses son enviados a buscarla.'), ('Perro callejero II', '7,4', 'Gilberto Gazcón', 'Gilberto Gazcón', '1h 36min', 'After serving his sentence, "perro" returns to his old neighborhood.'), ('She diao ying xiong chuan san ji', '6,3', 'Cheh Chang', 'Louis ChaCheh ChangKuang Ni', '1h 32min', "The third installment of The Brave Archer series brings Guo Jing and Huang Rong closer together as they struggle to find a cure for the Iron Palm Clan's deadly blows."), ('Shang Hai Tan da ye', '5,4', 'Tso Nam Lee', 'Po-Sheng Lu', None, 'La película se centra en las intrigas y los combates en medio de la ocupación japonesa de China.'), ('Carrera salvaje', '3,9', 'Antonio Margheriti', 'Marco Tullio GiordanaMassimo De RitaConcha Espina', '1h 35min', 'Paul, an ace driver and Nick, a wizard of mechanics, form a perfect team of auto racers. By winning a rigged race and he had to leave victory to a rider of a team in the pay of a mobster named Wronsky, our friends are forced to temporarily erase circuits; to escape the wrath of Wronsky.'), ('Asalto al casino', '3,7', 'Max H. Boulois', 'Max H. Boulois', '1h 44min', 'Sir Thomas Bedford orchestrates the heist of a Spanish casino, with the aid of a singer performing there. The police are aware of their activities, and a hostage situation arises.'))

# %%
# EXTRACCION DATOS IBDM Y LO GUARDAMOS EN LISTAS

driver = webdriver.Chrome()

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

# aceptamos cookies

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()

nota_imbd = []
direccion = []
guionista = []
argumento = []
duracion = []
nombre = []


for i in idOwner[:10]:
    driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
    sleep(5)
    nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
    try:        
        direccion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a').text)                                                                                   
        guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div').text)
        duracion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > ul > li:nth-child(3)').text)
        nota_imbd.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text)
    
    except:
        try:
            direccion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a').text)                                                  
            guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a').text)                                                   
            duracion.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/ul/li[2]').text)
        except:
            duracion.append(None)
        
    #try:
        #argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-1.eSoBYy').text)
    #except: 
        #print(i)
        # argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-0.caYjFF').text)
        
     
driver.close()

# %%
df_action = df_action.drop("Unnamed: 0", axis='columns')

# %%
df_action
# Out:
#        idOwner                       Title   Type  Year   Genre
# 0    tt0075859     De draken van Bruce Lee  Movie  1980  Action
# 1    tt0076321                Liu he ba fa  Movie  1980  Action
# 2    tt0076580               Qian zuo guai  Movie  1980  Action
# 3    tt0077634  The Great Skycopter Rescue  Movie  1980  Action
# 4    tt0076709                  Si wang ta  Movie  1980  Action
# ..         ...                         ...    ...   ...     ...
# 126  tt0101616                Coolie No. 1  Movie  1995  Action
# 127  tt0105881            Magkasangga 2000  Movie  1995  Action
# 128  tt0109178                   Automatic  Movie  1995  Action
# 129  tt0109033    Abducted II: The Reunion  Movie  1995  Action
# 130  tt0109536               The Dangerous  Movie  1995  Action
#
# [131 rows x 5 columns]

# %%
imdb_action = list(tuple(zip(nombre,nota,director,guionista,argumento,duracion)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 imdb_action = list(tuple(zip(nombre,nota,director,guionista,argumento,duracion)))
#
# NameError: name 'nombre' is not defined

# %%
imdb_action
# Out:
# [('La saga de Bruce Lee',
#   '4,3',
#   'Joseph Velasco',
#   'Kuang-Hsin Wu',
#   '',
#   '1h 31min'),
#  ('Los puños de la lealtad',
#   '6,3',
#   'Tien-Yung Hsu',
#   'Hsiang-Ju Sung',
#   '',
#   'NULL'),
#  ('Qian zuo guai', '5,3', 'John Woo', 'John Woo', '', '1h 41min'),
#  ('El gran desafío en helicóptero',
#   '6,3',
#   'Lawrence David Foldes',
#   'Lawrence David FoldesHenry EdwardsTony Crechales',
#   '',
#   'NULL'),
#  ('El último combate', '3,7', 'See-Yuen Ng', 'Tin-Shing Ho', '', '14'),
#  ('Shao Lin yu Wu Dang',
#   '6,6',
#   'Cheh Chang',
#   'Cheh ChangKuang Ni',
#   '',
#   '1h 41min'),
#  ('Duelo del Dragón y el Tigre',
#   '5,4',
#   'Bruce Le',
#   'Bruce LeFan Pan',
#   '',
#   'NULL'),
#  ("L'empreinte des géants",
#   '6,8',
#   'Robert Enrico',
#   'François ChevallierHortense DufourRobert Enrico',
#   '',
#   'NULL'),
#  ('Carlos el terrorista',
#   '4,6',
#   'René Cardona',
#   'René Cardona Jr.',
#   '',
#   '1h 37min'),
#  ('Ba jue', '4,5', 'Hsueh-Li Pao', 'Shu-Mei ChinYu ChuKuang Ni', '', 'NULL'),
#  ('Puño desnudo', '6,3', 'Cirio H. Santiago', 'Ken Metcalfe', '', 'R'),
#  ('Jie quan da dong kau',
#   '3,2',
#   'Lu-Po Tu',
#   'Ryong KeoLik CheungBolo Yeung',
#   '',
#   'NULL'),
#  ('La espada del samurái',
#   '7,1',
#   'Tsugunobu Kotani',
#   'William Overgard',
#   '',
#   '1h 44min'),
#  ('Perro callejero II',
#   '5,9',
#   'Gilberto Gazcón',
#   'Gilberto Gazcón',
#   '',
#   'NULL'),
#  ('She diao ying xiong chuan san ji',
#   '6,8',
#   'Cheh Chang',
#   'Louis ChaCheh ChangKuang Ni',
#   '',
#   '1h 32min'),
#  ('Shang Hai Tan da ye', '6,6', 'Tso Nam Lee', 'Po-Sheng Lu', '', 'NULL'),
#  ('Carrera salvaje',
#   '7,0',
#   'Antonio Margheriti',
#   'Marco Tullio GiordanaMassimo De RitaConcha Espina',
#   '',
#   'NULL'),
#  ('Asalto al casino',
#   '7,2',
#   'Max H. Boulois',
#   'Max H. Boulois',
#   '',
#   '1h 44min'),
#  ('Chakra',
#   '6,2',
#   'Rabindra Dharmaraj',
#   'Jaywant DalviRabindra Dharmaraj',
#   '',
#   'NULL'),
#  ('Burning Rubber', '3,4', 'Norman Cohen', 'Dale CuttsBill Flynn', '', 'NULL'),
#  ('Tennessee Stallion',
#   '3,9',
#   'Don Hulette',
#   'Frederick ColeDon HuletteJane Perry',
#   '',
#   'NULL'),
#  ('La conspiración de Shaolin',
#   '4,9',
#   'Chao-Yung Li',
#   'Hsiang-Kan Chu',
#   '',
#   '1h 30min'),
#  ('Shen diao xia lü',
#   '4,4',
#   'Cheh Chang',
#   'Louis ChaCheh ChangKuang Ni',
#   '',
#   '1h 40min'),
#  ('Shao Lin si',
#   '4,1',
#   'Hsin-Yen Chang',
#   'Hau SitShau-Chang Lu',
#   '',
#   '1h 40min'),
#  ('La cúspide',
#   '5,0',
#   'Peter Carter',
#   'Richard A. GuttmanIan Sutherland',
#   '',
#   '1h 28min'),
#  ('Calígula 3, la historia jamás contada',
#   '7,1',
#   "Joe D'Amato",
#   "George EastmanJoe D'AmatoMichele Soavi",
#   '',
#   '2h 10min'),
#  ('El imperio de la muerte',
#   '4,6',
#   'Brian Trenchard-Smith',
#   'Jon George',
#   '',
#   '18'),
#  ('Long de ying zi', '4,2', 'Bruce Li', 'Yuen King', '', '1h 24min'),
#  ('Yo soy la justicia', '5,0', 'Michael Winner', 'David Engelbach', '', '18'),
#  ('El reposo de los valientes',
#   '4,3',
#   'Lindsay Shonteff',
#   'Lindsay ShonteffJeremy Lee Francis',
#   '',
#   'NULL'),
#  ('Bing xue qing guan ying xiong dan',
#   '4,2',
#   'Hsueh-Li Pao',
#   'Louis ChaShu-Mei Chin',
#   '',
#   'NULL'),
#  ('Tian can bian',
#   '4,4',
#   'Chun-Ku Lu',
#   'Kuo-Yuan ChangChun-Ku LuYing Wong',
#   '',
#   'NULL'),
#  ('Fantasy Mission Force', '3,3', 'Yen-Ping Chu', 'Hsin Wei', '', 'R'),
#  ('Operación Camboya',
#   '2,5',
#   'Jun Gallardo',
#   'Rodolfo Dabao Jr.Don Gordon Bell',
#   '',
#   '1h 30min'),
#  ('Shao Lin yu Wu Dang',
#   '2,1',
#   'Chia-Hui Liu',
#   'Shu-Mei ChinPa-Ching HuangChi-kien Wong',
#   '',
#   '1h 27min'),
#  ('Yang guo yu xiao long nu',
#   '3,9',
#   'Shan Hua',
#   'Louis ChaNing TamNai-Pin Tsai',
#   '',
#   '1h 36min'),
#  ('Man tian shen fo', '3,0', 'Hsia Hsu', 'Chia Yeh', '', 'NULL'),
#  ('El precio del peligro',
#   '4,5',
#   'Yves Boisset',
#   'Robert SheckleyYves BoissetJean Curtelin',
#   '',
#   '1h 38min'),
#  ('USA, violación y venganza',
#   '5,6',
#   'José Luis Merino',
#   'José Luis Merino',
#   '',
#   'NULL'),
#  ('Qing ren kan dao',
#   '5,3',
#   'Yang-Ming Tsai',
#   'Lung KuHsiang-Ju Sung',
#   '',
#   'NULL'),
#  ('Shang Hai tan: Shi san tai bao',
#   '5,7',
#   'Cheh Chang',
#   'Cheh Chang',
#   '',
#   'NULL'),
#  ('Alley Cat', '4,8', 'Victor M. Ordonez', 'Robert E. Waters', '', 'R'),
#  ('Día de perros',
#   '4,3',
#   'Yves Boisset',
#   'Jean HermanMichel AudiardDominique Roulet',
#   '',
#   'NULL'),
#  ('Don Camilo',
#   '5,5',
#   'Terence Hill',
#   'Lori HillGiovanni Guareschi',
#   '',
#   'NULL'),
#  ("Les cavaliers de l'orage",
#   '4,3',
#   'Gérard Vergez',
#   'Gérard VergezDaniel BoulangerJean Giono',
#   '',
#   'NULL'),
#  ('Luna de miel y de sangre',
#   '2,6',
#   'Luis Antúnez',
#   'Jose Luís ArcelusGloria López Villaseñor',
#   '',
#   '1h 25min'),
#  ('Dreptate în lanturi',
#   '2,4',
#   'Dan Pita',
#   'Dan PitaMihai Stoian',
#   '',
#   'NULL'),
#  ('Final executor', '6,6', 'Romolo Guerrieri', 'Roberto Leoni', '', 'NULL'),
#  ('Confidentes de la muerte',
#   '5,2',
#   'Siu-Jun Wong',
#   'Siu-Jun Wong',
#   '',
#   'NULL'),
#  ('Long fa wei',
#   '3,5',
#   'Chung-Hsing Chao',
#   'Chung-Hsing Chao',
#   '',
#   '1h 38min'),
#  ('Meri Jung', '4,0', 'Subhash Ghai', 'Javed Akhtar', '', '2h 44min')]

# %%
imdb_action = zip()
# Out:
# ['La saga de Bruce Lee', 'Los puños de la lealtad', 'Qian zuo guai', 'El gran desafío en helicóptero', 'El último combate', 'Shao Lin yu Wu Dang', 'Duelo del Dragón y el Tigre', "L'empreinte des géants", 'Carlos el terrorista', 'Ba jue', 'Puño desnudo', 'Jie quan da dong kau', 'La espada del samurái', 'Perro callejero II', 'She diao ying xiong chuan san ji', 'Shang Hai Tan da ye', 'Carrera salvaje', 'Asalto al casino', 'Chakra', 'Burning Rubber', 'Tennessee Stallion', 'La conspiración de Shaolin', 'Shen diao xia lü', 'Shao Lin si', 'La cúspide', 'Calígula 3, la historia jamás contada', 'El imperio de la muerte', 'Long de ying zi', 'Yo soy la justicia', 'El reposo de los valientes', 'Bing xue qing guan ying xiong dan', 'Tian can bian', 'Fantasy Mission Force', 'Operación Camboya', 'Shao Lin yu Wu Dang', 'Yang guo yu xiao long nu', 'Man tian shen fo', 'El precio del peligro', 'USA, violación y venganza', 'Qing ren kan dao', 'Shang Hai tan: Shi san tai bao', 'Alley Cat', 'Día de perros', 'Don Camilo', "Les cavaliers de l'orage", 'Luna de miel y de sangre', 'Dreptate în lanturi', 'Final executor', 'Confidentes de la muerte', 'Long fa wei']

# %%
print(argumento)
# Out:
# ['Amma lives in Bijapur with her husband and son, Benwa. When a man attempts to sexually molest her, he is killed by her husband, the trio flee, but the husband is shot dead by the police. Amma re-locates to a shanty slum near Dharavi, Bombay, where Benwa grows up and shines shoes for a living. Amma is sexually active with Looka, a hoodlum and extortionist who shows up once in while, and also has a steady relationship with trucker, Anna. Both Looka and Anna are unaware of each other. Looka gets Benwa married to Amli from a nearby slum & Anna gets Amma a much better shelter. All seems to be going well until the Police come looking for an injured Looka, when he robs a pharmacy in order to get medicines for himself. Watch what happens when the Police arrive and find a visibly pregnant Amma with Looka, and the impact this will have on her relationship with Anna.\n—rAjOo (gunwanti@hotmail.com)']
