# %%
#!pip install sqlalchemy
#!pip install pymysql

# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# hemos hecho un pip install sqlalchemy
from sqlalchemy import create_engine 
from mysql.connector import Error

# %%
engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@127.0.0.1/CineParadiso')

# %%
#data = pd.read_csv ("xxxx.csv"))

# %%
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

try:
    mycursor.execute("CREATE DATABASE IF NOT EXISTS CineParadiso")
    print(mycursor)

except mysql.connector.Error as err:
    print(err)
    print("Error code:", err.errno)
    print("SOLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor: CREATE DATABASE IF NOT EXISTS CineParadi..

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Crear la tabla solo si no existe
query = """
CREATE TABLE IF NOT EXISTS film (
    film_id INT AUTO_INCREMENT PRIMARY KEY,
    idOwner VARCHAR(30),
    title VARCHAR(100),
    type VARCHAR(30),
    year VARCHAR(10),
    genre VARCHAR(30),
    screenwriter VARCHAR(50),
    management VARCHAR(50),
    plot VARCHAR(1000),
    length INT,
    rating VARCHAR(10)
)
"""

try:
    mycursor.execute(query)
    print("Table 'film' created successfully or already exists.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# Table 'film' created successfully or already exists.

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Crear la tabla solo si no existe
query = """
CREATE TABLE IF NOT EXISTS cast (
    cast_id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(50),
    birth VARCHAR(30),
    award VARCHAR(500),
    nomination VARCHAR(500),
    known_for VARCHAR(500)
)
"""

try:
    mycursor.execute(query)
    print("Table 'cast' created successfully or already exists.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# Table 'cast' created successfully or already exists.

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Crear la tabla 'oscars' solo si no existe
query = """
CREATE TABLE IF NOT EXISTS oscars (
    oscar_id INT AUTO_INCREMENT PRIMARY KEY,
    date VARCHAR(30),
    best_film VARCHAR(50),
    best_management VARCHAR(40),
    best_actor VARCHAR(40),
    best_actress VARCHAR(40),
    film_id INT
)
"""

try:
    mycursor.execute(query)
    print("Table 'oscars' created successfully or already exists.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# Table 'oscars' created successfully or already exists.

# %%
 #Conectar a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Crear la tabla 'film_cast_oscars' solo si no existe
query = """
CREATE TABLE IF NOT EXISTS film_cast (
    id_film_cast_oscars INT AUTO_INCREMENT PRIMARY KEY,
    film_id INT,
    cast_id INT,
    FOREIGN KEY (film_id) REFERENCES film(film_id)
        ON DELETE CASCADE ON UPDATE CASCADE,
    FOREIGN KEY (cast_id) REFERENCES `cast`(cast_id)
        ON DELETE CASCADE ON UPDATE CASCADE,
)
"""

try:
    mycursor.execute(query)
    print("Table 'film_cast' created successfully or already exists.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 9
# Error Code: 1064
# SQLSTATE 42000
# Message You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 9

# %%
try:
    # Conectar a la base de datos
    cnx = mysql.connector.connect(
        user="root",
        password="AlumnaAdalab",
        host="127.0.0.1",
        database="CineParadiso",
        auth_plugin='mysql_native_password'
    )
    
    if cnx.is_connected():
        print("Connected to MySQL database")

        # Leer el archivo CSV usando pandas
        csv_file = '../info_tablas_csv/Oscars.csv'  # Asegúrate de que el archivo esté en esta ubicación
        try:
            data_movies = pd.read_csv(csv_file)
        except FileNotFoundError:
            print(f"Error: The file {csv_file} was not found.")
            raise
        except pd.errors.EmptyDataError:
            print(f"Error: The file {csv_file} is empty.")
            raise
        except pd.errors.ParserError:
            print(f"Error: There was an error parsing the file {csv_file}.")
            raise

        # Preparar la conexión y el cursor
        mycursor = cnx.cursor()

        # Consulta SQL para insertar datos
        query = ('INSERT INTO oscars (date, best_film, best_management, best_actor, best_actress) VALUES (%s, %s, %s, %s, %s)')

        # Iterar sobre las filas del DataFrame y cargar los datos
        for _, row in data_movies.iterrows():
            try:
                # Convertir la fila a una tupla
                values = tuple(row)
                mycursor.execute(query, values)
                
            except mysql.connector.Error as err:
                print(f'Error insertando fila {row}: {err}')
            except Exception as e:
                print(f'Error inesperado insertando fila {row}: {e}')
        
        # Confirmar los cambios en la base de datos
        cnx.commit()
        print("Data loaded successfully into the 'oscars' table")

except mysql.connector.Error as e:
    print(f"Error connecting to MySQL database: {e}")

finally:
    # Cerrar el cursor y la conexión
    if cnx.is_connected():
        if mycursor:
            mycursor.close()
        cnx.close()
        print("Connection closed")
# Out:
# Connected to MySQL database
# Error insertando fila Unnamed: 0                                        0
# Fecha de ceremonia               14 de abrilde 1980
# Mejor película                    Kramer vs. Kramer
# Mejor dirección        R. Benton(Kramer vs. Kramer)
# Mejor actor           D. Hoffman(Kramer vs. Kramer)
# Mejor actriz                    S. Field(Norma Rae)
# idOwner                                         NaN
# Name: 0, dtype: object: Not all parameters were used in the SQL statement
# Error insertando fila Unnamed: 0                                           1
# Fecha de ceremonia                     31 de marzo1981
# Mejor película                         Ordinary People
# Mejor dirección            R. Redford(Ordinary People)
# Mejor actor                    R. De Niro(Raging Bull)
# Mejor actriz          S. Spacek(Coal Miner's Daughter)
# idOwner                                            NaN
# ...

# %%
# Conectar a la base de datos
try:
    cnx = mysql.connector.connect(
        user="root",
        password="AlumnaAdalab",
        host="127.0.0.1",
        database="CineParadiso",
        auth_plugin='mysql_native_password'
    )

    if cnx.is_connected():
        print("Connected to MySQL database")

        # Leer el archivo CSV usando pandas
        data_movies = pd.read_csv('../info_tablas_csv/Oscars.csv')

        # Preparar la conexión y el cursor
        mycursor = cnx.cursor()

        # Consulta SQL para insertar datos
        query = ('INSERT INTO oscars (date, best_film, best_management, best_actor, best_actress) VALUES (%s, %s, %s, %s, %s)')

        # Iterar sobre las filas del DataFrame y cargar los datos
        for _, row in data_movies.iterrows():
            try:
                # Convertir la fila a una tupla
                values = tuple(row)
                mycursor.execute(query, values)
                
            except mysql.connector.Error as err:
                print(f'Error insertando fila {row}: {err}')
        
        # Confirmar los cambios en la base de datos
        cnx.commit()
        print("Data loaded successfully into the 'oscars' table")

except Error as e:
    print(f"Error: {e}")

finally:
    # Cerrar el cursor y la conexión
    if cnx.is_connected():
        mycursor.close()
        cnx.close()
        print("Connection closed")
# Out:
# Connected to MySQL database
# Error insertando fila Unnamed: 0                                        0
# Fecha de ceremonia               14 de abrilde 1980
# Mejor película                    Kramer vs. Kramer
# Mejor dirección        R. Benton(Kramer vs. Kramer)
# Mejor actor           D. Hoffman(Kramer vs. Kramer)
# Mejor actriz                    S. Field(Norma Rae)
# idOwner                                         NaN
# Name: 0, dtype: object: Not all parameters were used in the SQL statement
# Error insertando fila Unnamed: 0                                           1
# Fecha de ceremonia                     31 de marzo1981
# Mejor película                         Ordinary People
# Mejor dirección            R. Redford(Ordinary People)
# Mejor actor                    R. De Niro(Raging Bull)
# Mejor actriz          S. Spacek(Coal Miner's Daughter)
# idOwner                                            NaN
# ...

# %%
print(data_movies.head())
# Out:
#    Unnamed: 0  Fecha de ceremonia       Mejor película  \
# 0           0  14 de abrilde 1980    Kramer vs. Kramer
# 1           1     31 de marzo1981      Ordinary People
# 2           2  29 de marzode 1982     Chariots of Fire
# 3           3     11 de abril1983               Gandhi
# 4           4   9 de abrilde 1984  Terms of Endearment
#
#                      Mejor dirección                    Mejor actor  \
# 0       R. Benton(Kramer vs. Kramer)  D. Hoffman(Kramer vs. Kramer)
# 1        R. Redford(Ordinary People)        R. De Niro(Raging Bull)
# 2                    W. Beatty(Reds)       H. Fonda(On Golden Pond)
# 3            R. Attenborough(Gandhi)      R. Duvall(Tender Mercies)
# 4  J. L. Brooks(Terms of Endearment)      R. Duvall(Tender Mercies)
#
#                        Mejor actriz  idOwner
# 0               S. Field(Norma Rae)      NaN
# 1  S. Spacek(Coal Miner's Daughter)      NaN
# 2        K. Hepburn(On Golden Pond)      NaN
# ...

# %%
try:
    # Conectar a la base de datos
    cnx = mysql.connector.connect(
        user="root",
        password="AlumnaAdalab",
        host="127.0.0.1",
        database="CineParadiso",
        auth_plugin='mysql_native_password'
    )

    if cnx.is_connected():
        print("Connected to MySQL database")

        # Leer el archivo CSV usando pandas
        csv_file = '../info_tablas_csv/FilmsCompleto.csv'
        try:
            data_movies = pd.read_csv(csv_file)
            print("CSV file loaded successfully")
            print(data_movies.head())  # Verifica el contenido del DataFrame
        except FileNotFoundError:
            print(f"Error: The file {csv_file} was not found.")
            raise
        except pd.errors.EmptyDataError:
            print(f"Error: The file {csv_file} is empty.")
            raise
        except pd.errors.ParserError:
            print(f"Error: There was an error parsing the file {csv_file}.")
            raise

        # Preparar la conexión y el cursor
        mycursor = cnx.cursor()

        # Consulta SQL para insertar datos
        query = ('INSERT INTO Film (idOwner, title, type, year, genre, screenwriter, management, plot, length, rating) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)')

        # Iterar sobre las filas del DataFrame y cargar los datos
        for _, row in data_movies.iterrows():
            try:
                # Convertir la fila a una tupla
                values = tuple(row)
                mycursor.execute(query, values)
                
            except mysql.connector.Error as err:
                print(f"Error insertando fila {row.to_dict()}: {err}")
            except Exception as e:
                print(f"Error inesperado insertando fila {row.to_dict()}: {e}")
        
        # Confirmar los cambios en la base de datos
        cnx.commit()
        print("Data loaded successfully into the 'Film' table")

except mysql.connector.Error as e:
    print(f"Error connecting to MySQL database: {e}")

finally:
    # Cerrar el cursor y la conexión
    if cnx.is_connected():
        if mycursor:
            mycursor.close()
        cnx.close()
        print("Connection closed")
# Out:
# Connected to MySQL database
# CSV file loaded successfully
#      idOwner                       Title   Type    Year   Genre  \
# 0  tt0077634  The Great Skycopter Rescue  Movie  1980.0  Action
# 1  tt0076709                  Si wang ta  Movie  1980.0  Action
# 2  tt0078428         Shao Lin yu Wu Dang  Movie  1980.0  Action
# 3  tt0077645               Mie jue qi qi  Movie  1980.0  Action
# 4  tt0079106      L'empreinte des géants  Movie  1980.0  Action
#
#                                  guionista  \
# 0  ('Donald G. Jackson', 'Randall Frakes')
# 1                        ('Siu-Jun Wong',)
# 2                        ('Anthony Jesu',)
# 3                     ('Robert Chappell',)
# 4   ('Charles B. Griffith', 'Lance Smith')
#
#                                        direccion  \
# 0  ('Paul Donovan', 'Digby Cook', 'Tony Randel')
# 1                                   Terence Hill
# 2                                       Bong Luk
# 3                              Cirio H. Santiago
# ...

# %%
import mysql.connector
import pandas as pd
from mysql.connector import Error

try:
    # Conexión a la base de datos
    cnx = mysql.connector.connect(
        user="root",
        password="AlumnaAdalab",
        host="127.0.0.1",
        database="CineParadiso",
        auth_plugin='mysql_native_password'
    )

    if cnx.is_connected():
        print("Connected to MySQL database")

        # Leer el archivo CSV usando pandas
        csv_file = '../info_tablas_csv/FilmsCompleto.csv'
        try:
            data_movies = pd.read_csv(csv_file)
            print("CSV file loaded successfully")
            print(data_movies.head())  # Verifica el contenido del DataFrame
        except FileNotFoundError:
            print(f"Error: The file {csv_file} was not found.")
            raise
        except pd.errors.EmptyDataError:
            print(f"Error: The file {csv_file} is empty.")
            raise
        except pd.errors.ParserError:
            print(f"Error: There was an error parsing the file {csv_file}.")
            raise

        # Preparar la conexión y el cursor
        mycursor = cnx.cursor()

        # Consulta SQL para insertar datos
        query = ('INSERT INTO Film (idOwner, title, type, year, genre, screenwriter, management, plot, length, rating) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)')

        # Iterar sobre las filas del DataFrame y cargar los datos
        for _, row in data_movies.iterrows():
            try:
                # Convertir la fila a una tupla
                values = tuple(row)
                if len(values) != 10:  # Verifica que el número de valores sea el correcto
                    print(f"Error: Expected 10 values, but got {len(values)}. Row data: {row}")
                    continue
                mycursor.execute(query, values)
                
            except mysql.connector.Error as err:
                print(f"Error insertando fila {row.to_dict()}: {err}")
            except Exception as e:
                print(f"Error inesperado insertando fila {row.to_dict()}: {e}")

        # Confirmar los cambios en la base de datos
        cnx.commit()
        print("Data loaded successfully into the 'Film' table")

except mysql.connector.Error as e:
    print(f"Error connecting to MySQL database: {e}")

finally:
    # Cerrar el cursor y la conexión
    if cnx.is_connected():
        if mycursor:
            mycursor.close()
        cnx.close()
        print("Connection closed")
# Out:
# Connected to MySQL database
# CSV file loaded successfully
#      idOwner                       Title   Type    Year   Genre  \
# 0  tt0077634  The Great Skycopter Rescue  Movie  1980.0  Action
# 1  tt0076709                  Si wang ta  Movie  1980.0  Action
# 2  tt0078428         Shao Lin yu Wu Dang  Movie  1980.0  Action
# 3  tt0077645               Mie jue qi qi  Movie  1980.0  Action
# 4  tt0079106      L'empreinte des géants  Movie  1980.0  Action
#
#                                  guionista  \
# 0  ('Donald G. Jackson', 'Randall Frakes')
# 1                        ('Siu-Jun Wong',)
# 2                        ('Anthony Jesu',)
# 3                     ('Robert Chappell',)
# 4   ('Charles B. Griffith', 'Lance Smith')
#
#                                        direccion  \
# 0  ('Paul Donovan', 'Digby Cook', 'Tony Randel')
# 1                                   Terence Hill
# 2                                       Bong Luk
# 3                              Cirio H. Santiago
# ...

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Leer el CSV donde tienes la información
data_movies = pd.read_csv('../info_tablas_csv/FilmsCompleto.csv')

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)

# Verificar que el reemplazo se realizó correctamente
print(data_movies.head())

# Definir la consulta de inserción
query = ('INSERT INTO Film (idOwner, title, type, year, genre, screenwriter, management, plot, length, rating) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)')

# Convertir DataFrame a una lista de tuplas
data_tuples = [tuple(x) for x in data_movies.to_numpy()]

# Iterar sobre cada tupla e insertar en la base de datos
for row in data_tuples:
    try:
        mycursor.execute(query, row)
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row[0]}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
#      idOwner                       Title   Type    Year   Genre  \
# 0  tt0077634  The Great Skycopter Rescue  Movie  1980.0  Action
# 1  tt0076709                  Si wang ta  Movie  1980.0  Action
# 2  tt0078428         Shao Lin yu Wu Dang  Movie  1980.0  Action
# 3  tt0077645               Mie jue qi qi  Movie  1980.0  Action
# 4  tt0079106      L'empreinte des géants  Movie  1980.0  Action
#
#                                  guionista  \
# 0  ('Donald G. Jackson', 'Randall Frakes')
# 1                        ('Siu-Jun Wong',)
# 2                        ('Anthony Jesu',)
# 3                     ('Robert Chappell',)
# 4   ('Charles B. Griffith', 'Lance Smith')
#
#                                        direccion  \
# 0  ('Paul Donovan', 'Digby Cook', 'Tony Randel')
# 1                                   Terence Hill
# 2                                       Bong Luk
# 3                              Cirio H. Santiago
# 4                                     Cheh Chang
#
# ...

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Leer el CSV donde tienes la información
data_movies = pd.read_csv("../info_tablas_csv/tabla_actores.csv")

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)

# Verificar que el reemplazo se realizó correctamente
print(data_movies.head())

# Definir la consulta de inserción
query = ('INSERT INTO Cast (name, birth, award, nomination, known_for) VALUES (%s,%s,%s,%s,%s)')

# Convertir DataFrame a una lista de tuplas
data_tuples = [tuple(x) for x in data_movies.to_numpy()]

# Iterar sobre cada tupla e insertar en la base de datos
for row in data_tuples:
    try:
        mycursor.execute(query, row)
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row[0]}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
#              Nombre                Nacimiento  \
# 0          Aldo Ray  25 de septiembre de 1926
# 1  William Marshall      19 de agosto de 1924
# 2      Terry Michos   26 de diciembre de 1953
# 3   Russell Johnson   10 de noviembre de 1924
# 4    Paul Tanashian       13 de marzo de 1960
#
#                                              Premios Nominaciones  \
# 0  {'premios ganados': ['1979 Ganador AFAA Award'...         None
# 1                                               None         None
# 2                                               None         None
# 3  {'premios ganados': ['2007 Nominado TV Land Aw...         None
# 4                                               None         None
#
#                                         Conocido por
# 0  ('No somos ángeles', 'La impetuosa', 'Nimh: El...
# 1  ('Drácula negro', 'Maverick', 'Grita Blácula g...
# 2  ('Los amos de la noche', 'El gran desafío en h...
# 3  ('La isla de Gílligan', 'Regreso a la Tierra',...
# ...

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Consulta para crear la tabla film_cast_oscars
query = """
CREATE TABLE IF NOT EXISTS film_cast (
    id_film_cast_oscars INT AUTO_INCREMENT PRIMARY KEY,
    film_id INT,
    cast_id INT,
    oscar_id INT,
    FOREIGN KEY (film_id) REFERENCES film(film_id)
    ON DELETE CASCADE ON UPDATE CASCADE,
    FOREIGN KEY (cast_id) REFERENCES `cast`(cast_id)
    ON DELETE CASCADE ON UPDATE CASCADE,
);
"""

try:
    mycursor.execute(query)
    print("Tabla film_cast creada correctamente.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
finally:
    mycursor.close()
    cnx.close()
# Out:
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 10
# Error Code: 1064
# SQLSTATE 42000
# Message You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 10

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Definición de la consulta para crear la tabla
query = """
CREATE TABLE IF NOT EXISTS film_cast (
    id_film_cast_oscars INT AUTO_INCREMENT PRIMARY KEY,
    film_id INT,
    cast_id INT,
    FOREIGN KEY (film_id) REFERENCES film(film_id)
    ON DELETE CASCADE ON UPDATE CASCADE,
    FOREIGN KEY (cast_id) REFERENCES `cast`(cast_id)
    ON DELETE CASCADE ON UPDATE CASCADE,

);
"""

try:
    mycursor.execute(query)
    print("Tabla 'film_cast_oscars' creada correctamente.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message:", err.msg)
finally:
    mycursor.close()
    cnx.close()
# Out:
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 10
# Error Code: 1064
# SQLSTATE 42000
# Message: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 10

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Datos de ejemplo para insertar
data_film_cast_oscars = [
    (1, 1),  # (film_id, cast_id)
    (2, 2)
]

# Consulta para insertar datos
query = 'INSERT INTO film_cast_oscars (film_id, cast_id) VALUES (%s, %s)'

# Función para verificar la existencia de claves foráneas antes de insertar
def check_foreign_keys(cursor, film_id, cast_id):
    cursor.execute("SELECT film_id FROM film WHERE film_id = %s", (film_id,))
    if cursor.fetchone() is None:
        return False

    cursor.execute("SELECT cast_id FROM `cast` WHERE cast_id = %s", (cast_id,))
    if cursor.fetchone() is None:
        return False

    #cursor.execute("SELECT oscar_id FROM oscars WHERE oscar_id = %s", (oscar_id,))
    #if cursor.fetchone() is None:
    #   return False

    return True

try:
    for record in data_film_cast_oscars:
        if check_foreign_keys(mycursor, record[0], record[1]):
            mycursor.execute(query, record)
        else:
            print(f"Invalid foreign key combination: {record}")
    cnx.commit()
    print("Datos insertados correctamente en la tabla film_cast_oscars.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
finally:
    mycursor.close()
    cnx.close()
# Out:
# Datos insertados correctamente en la tabla film_cast_oscars.

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Datos de ejemplo para insertar (sin el oscar_id)
data_film_cast = [
    (1, 1),  # (film_id, cast_id)
    (2, 2),
    (3, 3)
]

# Consulta para insertar datos
query = 'INSERT INTO film_cast_oscars (film_id, cast_id) VALUES (%s, %s)'

# Función para verificar la existencia de claves foráneas antes de insertar
def check_foreign_keys(cursor, film_id, cast_id):
    cursor.execute("SELECT film_id FROM film WHERE film_id = %s", (film_id,))
    if cursor.fetchone() is None:
        return False

    cursor.execute("SELECT cast_id FROM `cast` WHERE cast_id = %s", (cast_id,))
    if cursor.fetchone() is None:
        return False

    return True

try:
    for record in data_film_cast:
        if check_foreign_keys(mycursor, record[0], record[1]):
            mycursor.execute(query, record)
        else:
            print(f"Invalid foreign key combination: {record}")
    cnx.commit()
    print("Datos insertados correctamente en la tabla film_cast_oscars.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE:", err.sqlstate)
    print("Message:", err.msg)
finally:
    mycursor.close()
    cnx.close()

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Consulta para listar todas las tablas en la base de datos
query = "SHOW TABLES"

try:
    mycursor.execute(query)
    tables = mycursor.fetchall()
    print("Tablas en la base de datos 'CineParadiso':")
    for table in tables:
        print(table[0])
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message:", err.msg)
finally:
    mycursor.close()
    cnx.close()
# Out:
# Tablas en la base de datos 'CineParadiso':
# cast
# film
# oscars

# %%
import mysql.connector

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Verificar existencia de las tablas y crearlas si no existen

create_film_table = """
CREATE TABLE IF NOT EXISTS film (
    film_id INT AUTO_INCREMENT PRIMARY KEY,
    idOwner VARCHAR(30),
    title VARCHAR(100),
    type VARCHAR(30),
    year VARCHAR(10),
    genre VARCHAR(30),
    screenwriter VARCHAR(50),
    management VARCHAR(50),
    plot VARCHAR(1000),
    length INT,
    rating VARCHAR(10)
);
"""

create_cast_table = """
CREATE TABLE IF NOT EXISTS `cast` (
    cast_id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(50),
    birth VARCHAR(30),
    award VARCHAR(500),
    nomination VARCHAR(500),
    known_for VARCHAR(500)
);
"""

create_oscars_table = """
CREATE TABLE IF NOT EXISTS oscars (
    oscar_id INT AUTO_INCREMENT PRIMARY KEY,
    date VARCHAR(30),
    best_film VARCHAR(50),
    best_management VARCHAR(40),
    best_actor VARCHAR(40),
    best_actress VARCHAR(40)
);
"""

create_film_cast_table = """
CREATE TABLE IF NOT EXISTS film_cast_oscars (
    id_film_cast_oscars INT AUTO_INCREMENT PRIMARY KEY,
    film_id INT,
    cast_id INT,
    FOREIGN KEY (film_id) REFERENCES film(film_id)
    ON DELETE CASCADE ON UPDATE CASCADE,
    FOREIGN KEY (cast_id) REFERENCES `cast`(cast_id)
    ON DELETE CASCADE ON UPDATE CASCADE
);
"""

try:
    mycursor.execute(create_film_table)
    print("Tabla 'film' verificada/creada.")
    mycursor.execute(create_cast_table)
    print("Tabla 'cast' verificada/creada.")
    mycursor.execute(create_oscars_table)
    print("Tabla 'oscars' verificada/creada.")
    mycursor.execute(create_film_cast_table)
    print("Tabla 'film_cast' verificada/creada.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message:", err.msg)
finally:
    mycursor.close()
    cnx.close()
# Out:
# Tabla 'film' verificada/creada.
# Tabla 'cast' verificada/creada.
# Tabla 'oscars' verificada/creada.
# Tabla 'film_cast' verificada/creada.
