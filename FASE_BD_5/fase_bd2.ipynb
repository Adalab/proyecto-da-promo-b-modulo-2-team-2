# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# %%
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

try:
    mycursor.execute("CREATE DATABASE IF NOT EXISTS CineParadiso")
    print(mycursor)

except mysql.connector.Error as err:
    print(err)
    print("Error code:", err.errno)
    print("SOLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor: CREATE DATABASE IF NOT EXISTS CineParadi..

# %%
# Tabla FILM

cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

query = "CREATE TABLE film (film_id INT AUTO_INCREMENT PRIMARY KEY, idOwner VARCHAR (30), title VARCHAR (100), type VARCHAR (30), year VARCHAR (10), genre VARCHAR (30), screenwriter VARCHAR (200), management VARCHAR (200), plot VARCHAR (1000), length INT, rating VARCHAR (10))"

try:
    mycursor.execute(query)

    print(mycursor)
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor: CREATE TABLE film (film_id INT AUTO_INCR..

# %%
# Tabla CAST

cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()


query = "CREATE TABLE cast (cast_id INT AUTO_INCREMENT PRIMARY KEY, idOwner VARCHAR (10), name VARCHAR (50), birth VARCHAR (30), award VARCHAR (500), nomination VARCHAR (500), known_for VARCHAR (500))"
try: 
                                                                                           
    mycursor.execute(query)

    print(mycursor)
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor: CREATE TABLE cast (cast_id INT AUTO_INCR..

# %%
# Tabla OSCARS

cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()


query = "CREATE TABLE oscars (oscar_id INT AUTO_INCREMENT PRIMARY KEY, date VARCHAR (30), best_film VARCHAR (50), best_management VARCHAR (40), best_actor VARCHAR (40), best_actress VARCHAR (40))"

try:
    mycursor.execute(query)

    print(mycursor)
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor: CREATE TABLE oscars (oscar_id INT AUTO_I..

# %%
# Tabla FILM_CAST_OSCARS

cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()


query = ("""
         CREATE TABLE film_cast(
    id_film_cast INT AUTO_INCREMENT PRIMARY KEY,
    cast_id INT,
    idOwner VARCHAR (10),
    name VARCHAR (50),
    film_id INT, 
    title VARCHAR(50),
    FOREIGN KEY (film_id) REFERENCES film (film_id)
    ON DELETE CASCADE ON UPDATE CASCADE,
    FOREIGN KEY (cast_id) REFERENCES cast (cast_id)
    ON DELETE CASCADE ON UPDATE CASCADE);
    """)


try:
    mycursor.execute(query)

    print(mycursor)
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    
cnx.close()
# Out:
# MySQLCursor:
#          CREATE TABLE film_cast(
#     id..

# %%
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

## Leer el CSV donde tengo la info:

data_movies = pd.read_csv('../info_tablas_csv/Oscars.csv')

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)


query = 'INSERT INTO Oscars (date, best_film, best_management, best_actor, best_actress) VALUES (%s,%s,%s,%s,%s)'


for _, row in data_movies.iterrows():
    
    try:
        mycursor.execute(query, tuple(row))
    
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['id']}: {err}")
        
## Confirmar los cambios en la base de datos

cnx.commit()

## Cerrar el cursor y la conexión

mycursor.close()
cnx.close()

# %%
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

## Leer el CSV donde tengo la info:

data_movie = pd.read_csv('../info_tablas_csv/FilmsCompleto.csv')

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)



query = 'INSERT INTO film (idOwner, title, type, year, genre, screenwriter, management, plot, length, rating) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'


for _, row in data_movie.iterrows():
    
    try:
        mycursor.execute(query, tuple(row))
    
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['idOwner']}: {err}")
        
## Confirmar los cambios en la base de datos

cnx.commit()

## Cerrar el cursor y la conexión

mycursor.close()
cnx.close()

# %%
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

## Leer el CSV donde tengo la info:

data_movie = pd.read_csv('../info_tablas_csv/actor_final.csv')

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)



query = 'INSERT INTO cast (name, idOwner, birth, award, nomination, known_for) VALUES (%s,%s,%s,%s,%s,%s)'


for _, row in data_movie.iterrows():
    
    try:
        mycursor.execute(query, tuple(row))
    
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['idOwner']}: {err}")
        
## Confirmar los cambios en la base de datos

cnx.commit()

## Cerrar el cursor y la conexión

mycursor.close()
cnx.close()

# %%
cnx = mysql.connector.connect(user = "root", password = "AlumnaAdalab", host ="127.0.0.1", database = "CineParadiso",
    auth_plugin='mysql_native_password')

mycursor = cnx.cursor()

query = ("SELECT cast_id, idOwner, name, film_id, title FROM film INNER JOIN cast USING(idOwner)")

mycursor.execute(query)

tabla_cast_id_film_id = mycursor.fetchall()
print(tabla_cast_id_film_id)
# Out:
# [(365, 'tt0077634', 'Paul Tanashian', 1, 'The Great Skycopter Rescue'), (364, 'tt0077634', 'Russell Johnson', 1, 'The Great Skycopter Rescue'), (363, 'tt0077634', 'Terry Michos', 1, 'The Great Skycopter Rescue'), (362, 'tt0077634', 'William Marshall', 1, 'The Great Skycopter Rescue'), (361, 'tt0077634', 'Aldo Ray', 1, 'The Great Skycopter Rescue'), (343, 'tt0077634', 'Aldo Ray', 1, 'The Great Skycopter Rescue'), (5, 'tt0077634', 'Paul Tanashian', 1, 'The Great Skycopter Rescue'), (4, 'tt0077634', 'Russell Johnson', 1, 'The Great Skycopter Rescue'), (3, 'tt0077634', 'Terry Michos', 1, 'The Great Skycopter Rescue'), (2, 'tt0077634', 'William Marshall', 1, 'The Great Skycopter Rescue'), (1, 'tt0077634', 'Aldo Ray', 1, 'The Great Skycopter Rescue'), (370, 'tt0076709', 'Roy Chiao', 2, 'Si wang ta'), (369, 'tt0076709', 'Roy Horan', 2, 'Si wang ta'), (368, 'tt0076709', 'Jeong-lee Hwang', 2, 'Si wang ta'), (367, 'tt0076709', 'Tae-jeong Kim', 2, 'Si wang ta'), (366, 'tt0076709', 'Bruce Lee', 2, 'Si wang ta'), (10, 'tt0076709', 'Roy Chiao', 2, 'Si wang ta'), (9, 'tt0076709', 'Roy Horan', 2, 'Si wang ta'), (8, 'tt0076709', 'Jeong-lee Hwang', 2, 'Si wang ta'), (7, 'tt0076709', 'Tae-jeong Kim', 2, 'Si wang ta'), (6, 'tt0076709', 'Bruce Lee', 2, 'Si wang ta'), (375, 'tt0078428', 'Kei-San Chan', 3, 'Shao Lin yu Wu Dang'), (374, 'tt0078428', 'Feng Lu', 3, 'Shao Lin yu Wu Dang'), (373, 'tt0078428', 'Li Wang', 3, 'Shao Lin yu Wu Dang'), (372, 'tt0078428', 'Sheng Chiang', 3, 'Shao Lin yu Wu Dang'), (371, 'tt0078428', 'Meng Lo', 3, 'Shao Lin yu Wu Dang'), (15, 'tt0078428', 'Kei-San Chan', 3, 'Shao Lin yu Wu Dang'), (14, 'tt0078428', 'Feng Lu', 3, 'Shao Lin yu Wu Dang'), (13, 'tt0078428', 'Li Wang', 3, 'Shao Lin yu Wu Dang'), (12, 'tt0078428', 'Sheng Chiang', 3, 'Shao Lin yu Wu Dang'), (11, 'tt0078428', 'Meng Lo', 3, 'Shao Lin yu Wu Dang'), (381, 'tt0077645', 'Brad Harris', 4, 'Mie jue qi qi'), (380, 'tt0077645', 'Nadiuska', 4, 'Mie jue qi qi'), (379, 'tt0077645', 'Jeong-lee Hwang', 4, 'Mie jue qi qi'), (378, 'tt0077645', 'Richard Harrison', 4, 'Mie jue qi qi'), (377, 'tt0077645', 'Bruce Le', 4, 'Mie jue qi qi'), (376, 'tt0077645', 'Bruce Le', 4, 'Mie jue qi qi'), (21, 'tt0077645', 'Brad Harris', 4, 'Mie jue qi qi'), (20, 'tt0077645', 'Nadiuska', 4, 'Mie jue qi qi'), (19, 'tt0077645', 'Jeong-lee Hwang', 4, 'Mie jue qi qi'), (18, 'tt0077645', 'Richard Harrison', 4, 'Mie jue qi qi'), (17, 'tt0077645', 'Bruce Le', 4, 'Mie jue qi qi'), (16, 'tt0077645', 'Bruce Le', 4, 'Mie jue qi qi'), (386, 'tt0079106', 'Raimund Harmstorf', 5, "L'empreinte des géants"), (385, 'tt0079106', 'Andréa Ferréol', 5, "L'empreinte des géants"), (384, 'tt0079106', 'Mario Adorf', 5, "L'empreinte des géants"), (383, 'tt0079106', 'Serge Reggiani', 5, "L'empreinte des géants"), (382, 'tt0079106', 'Zoé Chauveau', 5, "L'empreinte des géants"), (26, 'tt0079106', 'Raimund Harmstorf', 5, "L'empreinte des géants"), (25, 'tt0079106', 'Andréa Ferréol', 5, "L'empreinte des géants"), (24, 'tt0079106', 'Mario Adorf', 5, "L'empreinte des géants"), (23, 'tt0079106', 'Serge Reggiani', 5, "L'empreinte des géants"), (22, 'tt0079106', 'Zoé Chauveau', 5, "L'empreinte des géants"), (391, 'tt0078941', 'Gloria Chávez', 6, 'Carlos el terrorista'), (390, 'tt0078941', 'Pablo Ferrel', 6, 'Carlos el terrorista'), (389, 'tt0078941', 'René Cardona III', 6, 'Carlos el terrorista'), (388, 'tt0078941', 'Alicia Encinas', 6, 'Carlos el terrorista'), (387, 'tt0078941', 'Andrés García', 6, 'Carlos el terrorista'), (396, 'tt0078726', 'Chung Wang', 7, 'Ba jue'), (395, 'tt0078726', 'Michael Wai-Man Chan', 7, 'Ba jue'), (394, 'tt0078726', 'Tao-Liang Tan', 7, 'Ba jue'), (393, 'tt0078726', 'Yun Ling', 7, 'Ba jue'), (392, 'tt0078726', 'Feng Hsu', 7, 'Ba jue'), (401, 'tt0078918', 'Frank Converse', 8, 'The Bushido Blade'), (400, 'tt0078918', 'Timothy Patrick Murphy', 8, 'The Bushido Blade'), (399, 'tt0078918', 'Mike Starr', 8, 'The Bushido Blade'), (398, 'tt0078918', 'Toshirô Mifune', 8, 'The Bushido Blade'), (397, 'tt00789 ...

# %%
tabla_cast_film = pd.DataFrame(tabla_cast_id_film_id, columns = ['cast_id','idOwner','name','film_id','title'])

# %%
tabla_cast_film

tabla_cast_film.to_csv('../info_tablas_csv/tabla_actor_film_conid.csv')

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

# Leer el CSV donde tienes la información
data_movies = pd.read_csv('../info_tablas_csv/tabla_actor_film_conid.csv')

# Reemplazar NaN con None para asegurar que los valores nulos se insertan correctamente
data_movies = data_movies.where(pd.notnull(data_movies), None)

# Verificar que el reemplazo se realizó correctamente
print(data_movies.head())

 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 674: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 673: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 295: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 294: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 679: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 678: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 677: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 676: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 675: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 300: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 299: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 298: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 297: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 296: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 684: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 683: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 682: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 681: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 680: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 305: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 304: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 303: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 302: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 301: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 689: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 688: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 687: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 686: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 685: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 310: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 309: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 308: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 307: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 306: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 694: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 693: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 692: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 691: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 690: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 315: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 314: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 313: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 312: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 311: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 700: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 699: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 698: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 697: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 696: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 695: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 321: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 320: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 319: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 318: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 317: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 316: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 706: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 705: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 704: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 703: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 702: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 701: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 345: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 344: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 327: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 326: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 325: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 324: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 323: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 322: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 714: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 713: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 712: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 711: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 710: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 709: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 708: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 707: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 353: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 352: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 351: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 350: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 349: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 348: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 347: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 346: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 335: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 334: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 333: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 332: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 331: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 330: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 329: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 328: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 719: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 718: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 717: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 716: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 715: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 358: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 357: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 356: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 355: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 354: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 340: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 339: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 338: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 337: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 336: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 721: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 720: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 360: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 359: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 342: 1054 (42S22): Unknown column 'idOwner' in 'field list'
# Error insertando fila 341: 1054 (42S22): Unknown column 'idOwner' in 'field list'

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

query = ('ALTER TABLE film_cast DROP COLUMN idOwner')

# Convertir DataFrame a una lista de tuplas 
data_tuples = [tuple(x) for x in data_movies.to_numpy()]

# Iterar sobre cada tupla e insertar en la base de datos
for row in data_tuples:
    try:
        mycursor.execute(query, row)
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row[0]}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

query = ('ALTER TABLE film_cast DROP COLUMN name')

# Convertir DataFrame a una lista de tuplas 
data_tuples = [tuple(x) for x in data_movies.to_numpy()]

# Iterar sobre cada tupla e insertar en la base de datos
for row in data_tuples:
    try:
        mycursor.execute(query, row)
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row[0]}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()

# %%
import mysql.connector
import pandas as pd

# Conexión a la base de datos
cnx = mysql.connector.connect(
    user="root",
    password="AlumnaAdalab",
    host="127.0.0.1",
    database="CineParadiso",
    auth_plugin='mysql_native_password'
)

mycursor = cnx.cursor()

query = ('ALTER TABLE film_cast DROP COLUMN title')

# Convertir DataFrame a una lista de tuplas 
data_tuples = [tuple(x) for x in data_movies.to_numpy()]

# Iterar sobre cada tupla e insertar en la base de datos
for row in data_tuples:
    try:
        mycursor.execute(query, row)
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row[0]}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
