# %%
import pandas as pd
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
from time import sleep

# %%
df_thriller = pd.read_csv("../FASE_API_1/Thriller.csv")

print(df_thriller)

idOwner = []

for i in df_thriller["idOwner"]:
    idOwner.append(i)
    

print(idOwner)
# Out:
#     Unnamed: 0    idOwner                                Title   Type  Year  \
# 0            0  tt0078508                            Wolf Lake  Movie  1980
# 1            1  tt0078805                           Attentatet  Movie  1980
# 2            2  tt0078895                           The Border  Movie  1980
# 3            3  tt0079145                        La femme flic  Movie  1980
# 4            4  tt0078053  Ópalo de fuego: Mercaderes del sexo  Movie  1980
# 5            5  tt0079181                      Fuego en el mar  Movie  1981
# 6            6  tt0079341      El infierno de todos tan temido  Movie  1981
# 7            7  tt0079706                              Paydirt  Movie  1981
# 8            8  tt0080608                Demasiado para Gálvez  Movie  1981
# 9            9  tt0080915                   Image of the Beast  Movie  1981
# 10          10  tt0082504                            Haathkadi  Movie  1982
# 11          11  tt0082342                     Espion, lève-toi  Movie  1982
# 12          12  tt0083906                               Eureka  Movie  1983
# 13          13  tt0083581              Asalto al Banco Central  Movie  1983
# 14          14  tt0084158                J'ai épousé une ombre  Movie  1983
# 15          15  tt0085528                           Les fauves  Movie  1984
# 16          16  tt0085627           I guerrieri dell'anno 2072  Movie  1984
# 17          17  tt0085645                       Hanyatt-homlok  Movie  1984
# 18          18  tt0085420               Delitto in Formula Uno  Movie  1984
# 19          19  tt0087882                        Parfait amour  Movie  1985
# 20          20  tt0086931                         Bahía blanca  Movie  1985
# 21          21  tt0087942                           Prime Risk  Movie  1985
# 22          22  tt0087344                        Godzilla 1985  Movie  1985
# 23          23  tt0089923                           Robachicos  Movie  1986
# 24          24  tt0088809                        Birds of Prey  Movie  1986
# 25          25  tt0089499                                 Lola  Movie  1986
# 26          26  tt0089118                                  F/X  Movie  1986
# 27          27  tt0089972                              Schmutz  Movie  1987
# 28          28  tt0090738                          Black Widow  Movie  1987
# 29          29  tt0090765              Boran - Zeit zum Zielen  Movie  1987
# 30          30  tt0092771               El complot dels anells  Movie  1988
# 31          31  tt0092966                   En toute innocence  Movie  1988
# 32          32  tt0094710                        Bangkok Story  Movie  1989
# 33          33  tt0093662                     Object of Desire  Movie  1990
# 34          34  tt0094666                      Any Man's Death  Movie  1990
# 35          35  tt0094857                   Chi se da feng bao  Movie  1990
# 36          36  tt0099587               Flight of the Intruder  Movie  1991
# 37          37  tt0099577                             Firehead  Movie  1991
# 38          38  tt0097928                         Murder Blues  Movie  1991
# 39          39  tt0100111                    Los mares del sur  Movie  1992
# 40          40  tt0101860                       Fatal Instinct  Movie  1992
# 41          41  tt0102000               Happy Birthday, Türke!  Movie  1992
# 42          42  tt0101395                          Backsliding  Movie  1992
# 43          43  tt0101759                     A Woman's Secret  Movie  1992
# 44          44  tt0101736                  Diplomatic Immunity  Movie  1992
# 45          45  tt0102253                  El laberinto griego  Movie  1993
# 46          46  tt0104683                           Laser Moon  Movie  1993
# 47          47  tt0102821                      Russian Holiday  Movie  1993
# 48          48  tt0104807                  Maang lui 72 siu si  Movie  1993
# 49          49  tt0103022               In a Moment of Passion  Movie  1993
# 50          50  tt0105054                  Sul filo del rasoio  Movie  1994
# 51          51  tt0105230                             Redheads  Movie  1994
# 52          52  tt0105463                            April One  Movie  1994
# 53          53  tt0106946                       Forced to Kill  Movie  1994
# 54          54  tt0106874                           Fatal Past  Movie  1994
# 55          55  tt0106479                       Breaking Point  Movie  1994
# 56          56  tt0095102              Les ennemis de la mafia  Movie  1995
# 57          57  tt0109034                      Above Suspicion  Movie  1995
# 58          58  tt0109532               Dangerous Indiscretion  Movie  1995
#
#        Genre
# 0   Thriller
# 1   Thriller
# 2   Thriller
# 3   Thriller
# 4   Thriller
# 5   Thriller
# 6   Thriller
# 7   Thriller
# 8   Thriller
# 9   Thriller
# 10  Thriller
# 11  Thriller
# 12  Thriller
# 13  Thriller
# 14  Thriller
# 15  Thriller
# 16  Thriller
# 17  Thriller
# 18  Thriller
# 19  Thriller
# 20  Thriller
# 21  Thriller
# 22  Thriller
# 23  Thriller
# 24  Thriller
# 25  Thriller
# 26  Thriller
# 27  Thriller
# 28  Thriller
# 29  Thriller
# 30  Thriller
# 31  Thriller
# 32  Thriller
# 33  Thriller
# 34  Thriller
# 35  Thriller
# 36  Thriller
# 37  Thriller
# 38  Thriller
# 39  Thriller
# 40  Thriller
# 41  Thriller
# 42  Thriller
# 43  Thriller
# 44  Thriller
# 45  Thriller
# 46  Thriller
# 47  Thriller
# 48  Thriller
# 49  Thriller
# 50  Thriller
# 51  Thriller
# 52  Thriller
# 53  Thriller
# 54  Thriller
# 55  Thriller
# 56  Thriller
# 57  Thriller
# 58  Thriller
# ['tt0078508', 'tt0078805', 'tt0078895', 'tt0079145', 'tt0078053', 'tt0079181', 'tt0079341', 'tt0079706', 'tt0080608', 'tt0080915', 'tt0082504', 'tt0082342', 'tt0083906', 'tt0083581', 'tt0084158', 'tt0085528', 'tt0085627', 'tt0085645', 'tt0085420', 'tt0087882', 'tt0086931', 'tt0087942', 'tt0087344', 'tt0089923', 'tt0088809', 'tt0089499', 'tt0089118', 'tt0089972', 'tt0090738', 'tt0090765', 'tt0092771', 'tt0092966', 'tt0094710', 'tt0093662', 'tt0094666', 'tt0094857', 'tt0099587', 'tt0099577', 'tt0097928', 'tt0100111', 'tt0101860', 'tt0102000', 'tt0101395', 'tt0101759', 'tt0101736', 'tt0102253', 'tt0104683', 'tt0102821', 'tt0104807', 'tt0103022', 'tt0105054', 'tt0105230', 'tt0105463', 'tt0106946', 'tt0106874', 'tt0106479', 'tt0095102', 'tt0109034', 'tt0109532']

# %%
# EXTRACCION DATOS IBDM Y LO GUARDAMOS EN LISTAS

driver = webdriver.Chrome()

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

# aceptamos cookies

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()

nota_imbd = []
direccion = []
guionista = []
argumento = []
duracion = []
nombre = []


for i in idOwner:
        driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
        sleep(5)
        
        nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
        
        try: 
                nota_imbd.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text)
        except:
                nota_imbd.append(None)

        
        try: 
                duracion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > ul > li:nth-child(3)').text)
        except:
                try:
                        duracion.append(driver.find_element('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/ul/li[2]').text)
                
                except:
                        duracion.append(None)  
                        
        
        try:
                argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr').text)
        except:
                argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-2.PeLXr').text)
        
        try:
        # Esperar hasta que el elemento esté presente en el DOM y sea visible
                elemento_argumento = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.fVGakt > div > div.sc-491663c0-10.RRTJr > section > p > span.sc-2d37a7c7-2.PeLXr'))
        )
                argumento.append(elemento_argumento.text)
        except:
                argumento.append(None)




        i = 0
        direccion_multiple = []
        try:    
                while True: 
                        i+=1
                        print('bucle 1 - i: ', i, ' iniciando....')
                        direccion_multiple.append(driver.find_element('css selector', f'#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li:nth-child({i}) > a').text)
                        print('bucle 1 - i: ', i, ' finalizado....')

        except:
                print('bucle 1 EXCEPT - i: ', i, ' finalizado....')
                if i > 1:
                        direccion.append(tuple(direccion_multiple))
                        continue
                else:
                        direccion.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a').text)                                                                                   
        
        

               
        i=0
        guionista_multiple = []
        try:
                while True:
                        i+=1
                        print('bucle 2 - i: ', i, ' iniciando....')
                        guionista_multiple.append(driver.find_element('css selector', f'#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li:nth-child({i}) > a').text)
                        print('bucle 2 - i: ', i, ' fin....')

        except:
                print('bucle 2 EXCEPT - i: ', i, ' fin....')
                if i > 1:
                        guionista.append(tuple(guionista_multiple))
                        continue
                else:
                        guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a').text)                                        
                          


driver.close()
# Out:
# bucle 1 - i:  1  iniciando....
# bucle 1 EXCEPT - i:  1  finalizado....
# bucle 2 - i:  1  iniciando....
# bucle 2 - i:  1  fin....
# bucle 2 - i:  2  iniciando....
# bucle 2 EXCEPT - i:  2  fin....
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/bs/l3gt0xp560x7j_9ydmgrywcw0000gn/T/ipykernel_23783/3551747772.py in <module>
#      45         try:
# ---> 46                 argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr').text)
#      47         except:
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     747
# --> 748         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     749
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010dd6a078 chromedriver + 5169272
# 1   chromedriver                        0x000000010dd61f4a chromedriver + 5136202
# 2   chromedriver                        0x000000010d8de36c chromedriver + 402284
# 3   chromedriver                        0x000000010d92b740 chromedriver + 718656
# 4   chromedriver                        0x000000010d92ba01 chromedriver + 719361
# 5   chromedriver                        0x000000010d970bc4 chromedriver + 1002436
# 6   chromedriver                        0x000000010d94eadd chromedriver + 862941
# 7   chromedriver                        0x000000010d96df57 chromedriver + 991063
# 8   chromedriver                        0x000000010d94e853 chromedriver + 862291
# 9   chromedriver                        0x000000010d91e5c6 chromedriver + 665030
# 10  chromedriver                        0x000000010d91ee4e chromedriver + 667214
# 11  chromedriver                        0x000000010dd2cc90 chromedriver + 4918416
# 12  chromedriver                        0x000000010dd31c8d chromedriver + 4938893
# 13  chromedriver                        0x000000010dd32365 chromedriver + 4940645
# 14  chromedriver                        0x000000010dd0dd74 chromedriver + 4791668
# 15  chromedriver                        0x000000010dd32659 chromedriver + 4941401
# 16  chromedriver                        0x000000010dcff544 chromedriver + 4732228
# 17  chromedriver                        0x000000010dd52828 chromedriver + 5072936
# 18  chromedriver                        0x000000010dd529e7 chromedriver + 5073383
# 19  chromedriver                        0x000000010dd61afe chromedriver + 5135102
# 20  libsystem_pthread.dylib             0x00007fff208df8fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff208db443 thread_start + 15
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/bs/l3gt0xp560x7j_9ydmgrywcw0000gn/T/ipykernel_23783/3551747772.py in <module>
#      46                 argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr').text)
#      47         except:
# ---> 48                 argumento.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-2.PeLXr').text)
#      49
#      50         try:
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     746             value = f'[name="{value}"]'
#     747
# --> 748         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     749
#     750     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     352         response = self.command_executor.execute(driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#     356             return response
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-2.PeLXr"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010dd6a078 chromedriver + 5169272
# 1   chromedriver                        0x000000010dd61f4a chromedriver + 5136202
# 2   chromedriver                        0x000000010d8de36c chromedriver + 402284
# 3   chromedriver                        0x000000010d92b740 chromedriver + 718656
# 4   chromedriver                        0x000000010d92ba01 chromedriver + 719361
# 5   chromedriver                        0x000000010d970bc4 chromedriver + 1002436
# 6   chromedriver                        0x000000010d94eadd chromedriver + 862941
# 7   chromedriver                        0x000000010d96df57 chromedriver + 991063
# 8   chromedriver                        0x000000010d94e853 chromedriver + 862291
# 9   chromedriver                        0x000000010d91e5c6 chromedriver + 665030
# 10  chromedriver                        0x000000010d91ee4e chromedriver + 667214
# 11  chromedriver                        0x000000010dd2cc90 chromedriver + 4918416
# 12  chromedriver                        0x000000010dd31c8d chromedriver + 4938893
# 13  chromedriver                        0x000000010dd32365 chromedriver + 4940645
# 14  chromedriver                        0x000000010dd0dd74 chromedriver + 4791668
# 15  chromedriver                        0x000000010dd32659 chromedriver + 4941401
# 16  chromedriver                        0x000000010dcff544 chromedriver + 4732228
# 17  chromedriver                        0x000000010dd52828 chromedriver + 5072936
# 18  chromedriver                        0x000000010dd529e7 chromedriver + 5073383
# 19  chromedriver                        0x000000010dd61afe chromedriver + 5135102
# 20  libsystem_pthread.dylib             0x00007fff208df8fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff208db443 thread_start + 15

# %%
# EXTRACCION DATOS IBDM Y LO GUARDAMOS EN LISTAS

driver = webdriver.Chrome()

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

# aceptamos cookies

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()

#nota_imbd = []
#direccion = []
#guionista = []
argumento = []
#duracion = []
nombre = []


for i in idOwner:
        driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
        sleep(5)
        
        nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
        
        try:
        # Esperar hasta que el elemento esté presente en el DOM y sea visible   CORRIGE EL SELECTOR DE LA PELICULA  SALE CORRECTO
                elemento_argumento = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.fVGakt > div > div.sc-491663c0-10.RRTJr > section > p > span.sc-2d37a7c7-2.PeLXr'))
        )
                argumento.append(elemento_argumento.text)
        except:
                argumento.append(None)


driver.close()

# %%
action_films_imdb = list(set(zip(nombre,nota_imbd,direccion,guionista,argumento,duracion_mins)))

# %%
print(action_films_imdb)

# %%
# EXTRACCION DATOS IBDM Y LO GUARDAMOS EN LISTAS


driver = webdriver.Chrome()

driver.get('https://www.imdb.com/')

driver.maximize_window()

sleep (3)

# aceptamos cookies

driver.find_element('css selector','#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd').click()

#nota_imbd = []
#direccion = []
guionista = []
#argumento = []
#duracion = []
nombre = []


for i in idOwner:
        driver.find_element('css selector','#suggestion-search').send_keys(i, Keys.ENTER)
        sleep(5)
        
        nombre.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span').text)
        


               
        i=0
        guionista_multiple = []
        try:
                while True:
                        i+=1
                        print('bucle 2 - i: ', i, ' iniciando....')
                        guionista_multiple.append(driver.find_element('css selector', f'#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li:nth-child({i}) > a').text)
                        print('bucle 2 - i: ', i, ' fin....')

        except:
                print('bucle 2 EXCEPT - i: ', i, ' fin....')
                if i > 1:
                        guionista.append(tuple(guionista_multiple))
                        continue
                else:
                        guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a').text)                                        


        try:
        # Prueba para verificar el selector
                elemento_guionista = WebDriverWait(driver, 10).until(
                EC.visibility_of_element_located((By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.fVGakt > div > div.sc-491663c0-10.RRTJr > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a'))
        )
                print(elemento_guionista.text)
        except Exception as e:
                print(f"Error al obtener guionista: {e}")

driver.quit()


driver.close()
# Out:
# bucle 2 - i:  1  iniciando....
# bucle 2 - i:  1  fin....
# bucle 2 - i:  2  iniciando....
# bucle 2 EXCEPT - i:  2  fin....
# bucle 2 - i:  1  iniciando....
# bucle 2 EXCEPT - i:  1  fin....
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/bs/l3gt0xp560x7j_9ydmgrywcw0000gn/T/ipykernel_23783/1060964129.py in <module>
#      38                         print('bucle 2 - i: ', i, ' iniciando....')
# ---> 39                         guionista_multiple.append(driver.find_element('css selector', f'#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li:nth-child({i}) > a').text)
#      40                         print('bucle 2 - i: ', i, ' fin....')
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     747
# --> 748         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     749
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li:nth-child(1) > a"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010a69e078 chromedriver + 5169272
# 1   chromedriver                        0x000000010a695f4a chromedriver + 5136202
# 2   chromedriver                        0x000000010a21236c chromedriver + 402284
# 3   chromedriver                        0x000000010a25f740 chromedriver + 718656
# 4   chromedriver                        0x000000010a25fa01 chromedriver + 719361
# 5   chromedriver                        0x000000010a2a4bc4 chromedriver + 1002436
# 6   chromedriver                        0x000000010a282add chromedriver + 862941
# 7   chromedriver                        0x000000010a2a1f57 chromedriver + 991063
# 8   chromedriver                        0x000000010a282853 chromedriver + 862291
# 9   chromedriver                        0x000000010a2525c6 chromedriver + 665030
# 10  chromedriver                        0x000000010a252e4e chromedriver + 667214
# 11  chromedriver                        0x000000010a660c90 chromedriver + 4918416
# 12  chromedriver                        0x000000010a665c8d chromedriver + 4938893
# 13  chromedriver                        0x000000010a666365 chromedriver + 4940645
# 14  chromedriver                        0x000000010a641d74 chromedriver + 4791668
# 15  chromedriver                        0x000000010a666659 chromedriver + 4941401
# 16  chromedriver                        0x000000010a633544 chromedriver + 4732228
# 17  chromedriver                        0x000000010a686828 chromedriver + 5072936
# 18  chromedriver                        0x000000010a6869e7 chromedriver + 5073383
# 19  chromedriver                        0x000000010a695afe chromedriver + 5135102
# 20  libsystem_pthread.dylib             0x00007fff208df8fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff208db443 thread_start + 15
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/bs/l3gt0xp560x7j_9ydmgrywcw0000gn/T/ipykernel_23783/1060964129.py in <module>
#      46                         continue
#      47                 else:
# ---> 48                         guionista.append(driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a').text)
#      49
#      50
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     746             value = f'[name="{value}"]'
#     747
# --> 748         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     749
#     750     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     352         response = self.command_executor.execute(driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#     356             return response
#
# /Applications/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010a69e078 chromedriver + 5169272
# 1   chromedriver                        0x000000010a695f4a chromedriver + 5136202
# 2   chromedriver                        0x000000010a21236c chromedriver + 402284
# 3   chromedriver                        0x000000010a25f740 chromedriver + 718656
# 4   chromedriver                        0x000000010a25fa01 chromedriver + 719361
# 5   chromedriver                        0x000000010a2a4bc4 chromedriver + 1002436
# 6   chromedriver                        0x000000010a282add chromedriver + 862941
# 7   chromedriver                        0x000000010a2a1f57 chromedriver + 991063
# 8   chromedriver                        0x000000010a282853 chromedriver + 862291
# 9   chromedriver                        0x000000010a2525c6 chromedriver + 665030
# 10  chromedriver                        0x000000010a252e4e chromedriver + 667214
# 11  chromedriver                        0x000000010a660c90 chromedriver + 4918416
# 12  chromedriver                        0x000000010a665c8d chromedriver + 4938893
# 13  chromedriver                        0x000000010a666365 chromedriver + 4940645
# 14  chromedriver                        0x000000010a641d74 chromedriver + 4791668
# 15  chromedriver                        0x000000010a666659 chromedriver + 4941401
# 16  chromedriver                        0x000000010a633544 chromedriver + 4732228
# 17  chromedriver                        0x000000010a686828 chromedriver + 5072936
# 18  chromedriver                        0x000000010a6869e7 chromedriver + 5073383
# 19  chromedriver                        0x000000010a695afe chromedriver + 5135102
# 20  libsystem_pthread.dylib             0x00007fff208df8fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff208db443 thread_start + 15

# %%
thriller_films_imdb = list(set(zip(nombre,guionista)))

# %%
print(thriller_films_imdb)
# Out:
# [('Cacería humana', ('Burt Kennedy',))]

# %%
duracion_mins = []

for peli in duracion:
        
        if peli == None:
                duracion_mins.append(None)
                
        elif 'h' in peli:
                horas,minutos = peli.split('h')
                horas = int(horas.strip())
                minutos = int(minutos.replace('min', '').strip())
                total_minutos = horas * 60 + minutos
                duracion_mins.append(total_minutos)

        elif 'min' in peli:

                minutos = int(peli.replace('min'))
                total_minutos = int(peli.replace('min', '').strip())
                duracion_mins.append(total_minutos)

# %%
thriller_films_imdb = list(set(zip(nombre,nota_imbd,direccion,guionista,argumento,duracion_mins)))

# %%
print(thriller_films_imdb)
# Out:
# [('Defcon 4', '4,5', ('Paul Donovan', 'Digby Cook', 'Tony Randel'), ('Donald G. Jackson', 'Randall Frakes'), 'Two men and a woman circle the globe in a satellite armed with a nuclear device. The third world war breaks out, and a few months later the satellite crashes. They survive the crash but one man gets killed by survivors and the other man gets caught. The woman stays by the remains of the the satellite but is soon caught by evil punks who have taken power.', 88), ('Don Camilo', '5,6', 'Terence Hill', ('Siu-Jun Wong',), "A priest helps the small town he's stationed in to resolve conflicts by working together.", 126), ('Hei hai ba wang hua', '5,8', 'Bong Luk', ('Anthony Jesu',), 'The 1990 Hong Kong action classic, starring Yukari Oshima, is titled Brave Young Girls in the U.S. It is a very interesting story about two beautiful young women who are completely different. One woman is a skilled martial artist/police officer and the other is a prostitute, but they figure out that it is much better to work together to solve their problems. Otherwise... Leer todo', 91), ('Equalizer 2000', '4,1', 'Cirio H. Santiago', ('Robert Chappell',), 'Una despiadada banda de vehículos domina el páramo postapocalíptico. Hasta que un héroe musculoso llamado Slade construye la ametralladora definitiva, la Equalizer 2000, y declara la guerra al líder de la banda.', 85), ('Guo jiang', '6,4', 'Cheh Chang', ('Charles B. Griffith', 'Lance Smith'), '1936, the Japanese are allied with the Kuomintang member called Liu Shaoji, during a Sichuan Opera he saw the beautiful Hua Yunfang, and he decided that he wants her.', 78), ('Shen diao xia lü', '5,4', 'Cheh Chang', ('George Eastman', "Joe D'Amato", 'Michele Soavi'), 'Brave Archer and His Mate is the fourth in a series originally starring international favorite Alexander Fu Sheng as master martial artist Kuo Tsing. Kuo Chui is the new hero who is out to defeat the mass murderer of his martial arts masters.', 100), ('Yang guo yu xiao long nu', '5,9', 'Shan Hua', ('Cheh Chang',), 'Little Dragon Maiden mixes the old with the new to create pure golden magic as kung-fu fighting veterans Chen Kuan-Tai and Lo Lieh join relative newcomer Leslie Cheung in a far-out swordplay love story that rocks.', 96), ('Shang Hai Tan da ye', '5,4', 'Tso Nam Lee', ('Max H. Boulois',), 'La película se centra en las intrigas y los combates en medio de la ocupación japonesa de China.', None), ('Ba jue', '5,4', 'Hsueh-Li Pao', ('Gilberto Gazcón',), 'A new bandit with superb kung fu causes panic and fear among the merchants of Wuiyang County. The merchants hire Wu Chin Ping to escort boxes of beautiful and previous stones to Wuiyang County. Wu gathers a group of experienced and courageous martial artists to protect the treasure and kill the masked bandit.', 98), ('Escuadrón: Counterforce', '4,3', 'José Antonio de la Loma', ('AAV Creative Unit', 'Godfrey Ho'), 'Un equipo de especialistas es enviado para proteger al líder de un país de Oriente Próximo de un dictador vecino que tiene designios sobre su país.', 98), ('Detective alienígena', '4,2', ('Vik Rubenfeld',), ('Mikel Angel', 'Joe Tornatore'), 'Un extraterrestre de un planeta lejano que trabaja como investigador privado en la Tierra se ve envuelto en una búsqueda para recuperar una droga poderosamente adictiva que fue enviada a la Tierra en un disco negro.', 95), ('Da Shang Hai 1937', '6,3', 'Cheh Chang', ('Philip Cheng', 'Gerald Liu', 'Yuen-Leung Poon'), 'In August 1937, Japanese troops occupied Shanghai. Three leaders in Shanghai go their separate ways: Jinrong Huang never sees other people; Xiaolin Zhang makes a great fortune and Yuesheng Du leaves for HongKong.', 115), ('Yo soy la justicia', '6,0', ('Michael Winner',), ('Shu-Mei Chin', 'Pa-Ching Huang', 'Chi-kien Wong'), 'El arquitecto Paul Kersey se convierte en vigilante de nuevo cuando intenta encontrar a los cinco matones callejeros que asesinaron a su hija y su ama de llaves, esta vez en las oscuras calles de Los Ángeles.' ...

# %%
thriller_films_imdb_df = pd.DataFrame(action_films_imdb, columns = ["nombre", "nota imdb", "direccion", "guionista", "sinopsis", "duracion (minutos)"])

# %%
thriller_films_imdb_df
# Out:
#                               nombre nota imdb  \
# 0                           Defcon 4       4,5
# 1                         Don Camilo       5,6
# 2                Hei hai ba wang hua       5,8
# 3                     Equalizer 2000       4,1
# 4                          Guo jiang       6,4
# ..                               ...       ...
# 81                     City of night       5,0
# 82                     Tian can bian       7,1
# 83                Perro callejero II       7,4
# 84                     The Occultist       2,5
# 85  She diao ying xiong chuan san ji       6,3
#
#                                   direccion  \
# 0   (Paul Donovan, Digby Cook, Tony Randel)
# 1                              Terence Hill
# 2                                  Bong Luk
# 3                         Cirio H. Santiago
# 4                                Cheh Chang
# ..                                      ...
# 81                           David Mitchell
# 82                               Chun-Ku Lu
# 83                          Gilberto Gazcón
# 84                              Tim Kincaid
# 85                               Cheh Chang
#
#                                             guionista  \
# 0                 (Donald G. Jackson, Randall Frakes)
# 1                                     (Siu-Jun Wong,)
# 2                                     (Anthony Jesu,)
# 3                                  (Robert Chappell,)
# 4                  (Charles B. Griffith, Lance Smith)
# ..                                                ...
# 81                 (Nadia Caillou, Harry Alan Towers)
# 82                                        (Chia Yeh,)
# 83                                     (Po-Sheng Lu,)
# 84             (Pierluigi Ciriaci, Dardano Sacchetti)
# 85  (Marco Tullio Giordana, Massimo De Rita, Conch...
#
#                                              sinopsis  duracion (minutos)
# 0   Two men and a woman circle the globe in a sate...                88.0
# 1   A priest helps the small town he's stationed i...               126.0
# 2   The 1990 Hong Kong action classic, starring Yu...                91.0
# 3   Una despiadada banda de vehículos domina el pá...                85.0
# 4   1936, the Japanese are allied with the Kuomint...                78.0
# ..                                                ...                 ...
# 81  In the same vein as Cain and Abel, here we hav...                92.0
# 82  Hsu Shao-chiang stars as a veritable "Spider-S...                89.0
# 83  After serving his sentence, "perro" returns to...                96.0
# 84  Un detective ciborg es contratado para protege...                82.0
# 85  The third installment of The Brave Archer seri...                92.0
#
# [86 rows x 6 columns]

# %%
thriller_films_imdb_df.to_csv('Action_imdb.csv')
